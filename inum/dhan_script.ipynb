# %%
import pandas as pd

# %%
csv = pd.read_csv("../api-scrip-master.csv")
csv
# Out:
# /var/folders/k6/3m775mv9323gx_xrv6hyr3340000gn/T/ipykernel_71226/3929536378.py:1: DtypeWarning: Columns (14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv = pd.read_csv("../api-scrip-master.csv")
#        SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 0                  BSE           C               1026077              FUTCUR
# 1                  BSE           C               1026078              FUTCUR
# 2                  BSE           C               1026079              FUTCUR
# 3                  BSE           C               1026080              FUTCUR
# 4                  BSE           C               1026081              FUTCUR
# ...                ...         ...                   ...                 ...
# 167708             NSE           M                127754              OPTFUT
# 167709             NSE           M                127755              OPTFUT
# ...

# %%
NSE_CSV = csv[csv["SEM_EXM_EXCH_ID"] == 'NSE']
# NSE_CSV = NSE_CSV[NSE_CSV["SEM_INSTRUMENT_NAME"] == "OPTIDX"]
# NSE_CSV = NSE_CSV[NSE_CSV["SEM_EXPIRY_DATE"].str.contains("2024-10-03")]
# NSE_CSV = NSE_CSV[NSE_CSV["SEM_STRIKE_PRICE"] == 25500.0]
# NSE_CSV = NSE_CSV[NSE_CSV["SEM_OPTION_TYPE"] == "PE"]
NSE_CSV = NSE_CSV[NSE_CSV["SEM_SMST_SECURITY_ID"] == 58530]
NSE_CSV
# Out:
#        SEM_EXM_EXCH_ID SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 129148             NSE           D                 58530              OPTIDX
#
#         SEM_EXPIRY_CODE      SEM_TRADING_SYMBOL  SEM_LOT_UNITS  \
# 129148                0  NIFTY-Oct2024-25400-PE           25.0
#
#              SEM_CUSTOM_SYMBOL      SEM_EXPIRY_DATE  SEM_STRIKE_PRICE  \
# 129148  NIFTY 03 OCT 25400 PUT  2024-10-03 14:30:00           25400.0
#
#        SEM_OPTION_TYPE  SEM_TICK_SIZE SEM_EXPIRY_FLAG  \
# 129148              PE            5.0               W
#
#        SEM_EXCH_INSTRUMENT_TYPE SEM_SERIES SM_SYMBOL_NAME
# 129148                       OP        NaN            NaN
